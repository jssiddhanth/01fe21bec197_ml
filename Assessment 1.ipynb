# %%
num = int(input("Enter a number: "))

flag = False

if num == 1:
    print(num, "is not a prime number")
elif num > 1:
    for i in range(2, num):
        if (num % i) == 0:
            flag = True
            break


    if flag:
        print(num, "is not a prime number")
    else:
        print(num, "is a prime number")
        #if: (n % 3 == 0 and n % 7 == 0 and n % 9 == 0 and n % 11) == 0:
             # print("Divisible by 3, 7, 9, 11")
# Out:
# Enter a number: 3
# 3 is a prime number

# %%
def check(str):

	for i in range(0, int(len(str)/2)):
		if str[i] != str[len(str)-i-1]:
			return 0
	return 1

s = str(input("Enter string "))
ans = check(s)

if (ans==1):
	print("String is a palindrome")
else:
	print("String is not a palindrome")
# Out:
# Enter string gadag
# String is a palindrome

# %%
lis1 = []
lis2 = []
lis3 = []

x = int(input("Enter number of elements: "))

for i in range(x):
    y = int(input("Enter a number: "))
    lis1.append(y)

for num in lis1:
    if num % 2 == 0:
        print("Even number:", num)
        lis2.append(num)
    else:
        print("Odd number:", num)
        lis3.append(num)

print("All numbers:", lis1)
print("Even numbers:", lis2)
print("Odd numbers:", lis3)
# Out:
# Enter number of elements: 4
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Enter a number: 5
# Even number: 2
# Odd number: 3
# Even number: 4
# Odd number: 5
# All numbers: [2, 3, 4, 5]
# Even numbers: [2, 4]
# Odd numbers: [3, 5]

# %%
n=input("Enter row value ")
for i in range(1, 5):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# Enter row value4
# *
# **
# ***
# ****
